# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None

# %%
path = './data'

# menyiapkan seluruh dataset e-commerce
customers_df = pd.read_csv(os.path.join(path,'customers_dataset.csv'))
geolocation_df = pd.read_csv(os.path.join(path,'geolocation_dataset.csv'))
order_items_df = pd.read_csv(os.path.join(path,'order_items_dataset.csv'))
order_payments_df = pd.read_csv(os.path.join(path,'order_payments_dataset.csv'))
order_reviews_df = pd.read_csv(os.path.join(path,'order_reviews_dataset.csv'))
orders_df = pd.read_csv(os.path.join(path,'orders_dataset.csv'))
product_category_name_translation = pd.read_csv(os.path.join(path,'product_category_name_translation.csv'))
products_df = pd.read_csv(os.path.join(path,'products_dataset.csv'))
sellers_df = pd.read_csv(os.path.join(path,'sellers_dataset.csv'))

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Langkah pertama dalam analisis ini yaitu dengan mengeksplor semua dataset. Proses ini memiliki tujuan antara lain :
# 1. membuat pertanyaan analisis atau bisnis yang ingin dicari jawabannya.
# 2. melakukan eksplorasi terhadap setiap data untuk mencari insight menarik guna menjawab pertanyaan bisnis tersebut.

# %% [markdown]
# ### Menganalisis customers dataset

# %%
customers_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# Berdasarkan output pada kode di atas, dapat dilihat bahwa dataset customers tidak memiliki nilai kosong.

# %%
customers_df.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# ### Menganalisis geolocation dataset

# %%
geolocation_df
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %% [markdown]
# Berdasarkan output pada kode di atas, dapat dilihat bahwa dataset tidak memiliki nilai kosong.

# %%
geolocation_df.describe(include="all")
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                  1.000163e+06     1.000163e+06     1.000163e+06
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   3.657417e+04    -2.117615e+01    -4.639054e+01
# std                    3.054934e+04     5.715866e+00     4.269748e+00
# min                    1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                    1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                    2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                    6.350400e+04    -1.997962e+01    -4.376771e+01
# max                    9.999000e+04     4.506593e+01     1.211054e+02
#
#        geolocation_city geolocation_state
# count           1000163           1000163
# ...

# %% [markdown]
# ### Menganalisis order items dataset

# %%
order_items_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_df.describe(include='all')
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %% [markdown]
# ### Menganalisis order payments dataset

# %%
order_payments_df
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# Berdasarkan output pada kode di atas, dapat dilihat bahwa dataset tidak memiliki nilai kosong.

# %%
order_payments_df.describe(include='all')
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# ### Menganalisis order reviews dataset

# %%
order_reviews_df
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# Pada kode di atas, dapat dilihat ada beberapa kolom yang kosong pada dataset order review. Namun, dalam kasus ini review dari customer itu bersifat opsional. Cell kosong dalam dataset ini tidak perlu dibersihkan karena merupakan kolom review dari customer. Pada dataset ini kita dapat mengubah tipe data pada kolom 'review_creation_date' dan 'review_answer_timestamp' menjadi datetime.

# %%
order_reviews_df['review_creation_date'] = pd.to_datetime(order_reviews_df['review_creation_date'])
order_reviews_df['review_answer_timestamp'] = pd.to_datetime(order_reviews_df['review_answer_timestamp'])

# %%
order_reviews_df.describe(include='all',datetime_is_numeric=True)
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# ...

# %% [markdown]
# ### Menganalisis orders dataset

# %%
orders_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_df[orders_df.isna().any(axis=1)]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %% [markdown]
# Dapat dilihat data yang kosong pada orders dataset hanya terdapat pada kolom 'order_approved_at', 'order_delivered_carrier_date' dan 'order_delivered_customer_date'. Hal ini juga disebabkan oleh beberapa faktor seperti, order status yang belum selesai, order yang tidak tersedia, hingga order yang dibatalkan. Dalam kasus ini data kosong tidak perlu diproses lebih lanjut. Kita dapat mengubah tipe data pada kolom 'order_approved_at', 'order_delivered_carrier_date', 'order_purchase_timestamp', 'order_delivered_customer_date', dan 'order_estimated_delivery_date' menjadi datetime.

# %%
orders_df['order_approved_at'] = pd.to_datetime(orders_df['order_approved_at'])
orders_df['order_delivered_carrier_date'] = pd.to_datetime(orders_df['order_delivered_carrier_date'])
orders_df['order_delivered_customer_date'] = pd.to_datetime(orders_df['order_delivered_customer_date'])
orders_df['order_purchase_timestamp'] = pd.to_datetime(orders_df['order_purchase_timestamp'])
orders_df['order_estimated_delivery_date'] = pd.to_datetime(orders_df['order_estimated_delivery_date'])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
orders_df.describe(include='all',datetime_is_numeric=True)
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# count         99441                          99441
# ...

# %% [markdown]
# ### Menganalisis product_category_name_translation

# %%
product_category_name_translation
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
product_category_name_translation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# ### Menganalisis products dataset

# %%
products_df
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products_df[products_df.isna().any(axis=1)]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
products_df.groupby(products_df['product_id']).count()
# Out:
#                                   product_category_name  product_name_lenght  \
# product_id
# 00066f42aeeb9f3007548bb9d3f33c38                      1                    1
# 00088930e925c41fd95ebfe695fd2655                      1                    1
# 0009406fd7479715e4bef61dd91f2462                      1                    1
# 000b8f95fcb9e0096488278317764d19                      1                    1
# 000d9be29b5207b54e86aa1b1ac54872                      1                    1
# ...                                                 ...                  ...
# fff6177642830a9a94a0f2cba5e476d1                      1                    1
# fff81cc3158d2725c0655ab9ba0f712c                      1                    1
# fff9553ac224cec9d15d49f5a263411f                      1                    1
# fffdb2d0ec8d6a61f0a0a0db3f25b441                      1                    1
# fffe9eeff12fcbd74a2f2b007dde0c58                      1                    1
#
# ...

# %% [markdown]
# Dapat dilihat pada output kode di atas, terdapat beberapa data yang kurang lengkap dalam products dataset. Data yang kosong dapat berupa nama serta deskripsi produk. Dalam kasus ini, data kosong tidak dapat diproses karena merupakan deskripsi dari produk dan tidak terdapat data tambahan untuk melengkapi dataset ini.

# %% [markdown]
# ### Menganalisis sellers dataset

# %%
sellers_df
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# # Hasil Exploratory Data Analysis

# %% [markdown]
# Setelah mengecek dan melihat dataset secara keseluruhan ada beberapa pertanyaan yang muncul, yaitu :
# 1. bagaimana performa penjualan e-commerce ?
# 2. produk apa saja yang paling banyak diorder ?
# 3. bagaimana analisis RFM customer pada e-commerce ?

# %% [markdown]
# # Menganalisis performa penjualan e-commerce

# %%
orders_df.groupby(orders_df['order_status']).count()
# Out:
#               order_id  customer_id  order_purchase_timestamp  \
# order_status
# approved             2            2                         2
# canceled           625          625                       625
# created              5            5                         5
# delivered        96478        96478                     96478
# invoiced           314          314                       314
# processing         301          301                       301
# shipped           1107         1107                      1107
# unavailable        609          609                       609
#
#               order_approved_at  order_delivered_carrier_date  \
# order_status
# approved                      2                             0
# canceled                    484                            75
# created                       0                             0
# delivered                 96464                         96476
# invoiced                    314                             0
# ...

# %% [markdown]
# Untuk menganalisis bagaimana performa penjualan e-commerce, analisis dilakukan dengan melihat total order yang berhasil dideliver pada customer melalui kolom 'order_status'. Kolom tersebut berisi status order customer. Order status 'delivered' menyatakan bahwa transaksi berhasil dan barang telah dikirim.  Karena pada kolom order status masih terdapat beberapa data yang menyatakan order tidak berhasil seperti status 'cancelled' atau 'unavailable', maka kita dapat melakukan analisis penjualan untuk order status 'delivered'.

# %% [markdown]
# ### Analisis penjualan berdasarkan tahun

# %%
# mengambil data dimana order telah berhasil diterima oleh customer
sales_df = orders_df[orders_df['order_status']=='delivered']
sales_df['year']=sales_df['order_purchase_timestamp'].dt.year
grouped_sales_by_year = sales_df.groupby(sales_df['year']).count().reset_index()
grouped_sales_by_year
# Out:
#    year  order_id  customer_id  order_status  order_purchase_timestamp  \
# 0  2016       267          267           267                       267
# 1  2017     43428        43428         43428                     43428
# 2  2018     52783        52783         52783                     52783
#
#    order_approved_at  order_delivered_carrier_date  \
# 0                267                           267
# 1              43414                         43426
# 2              52783                         52783
#
#    order_delivered_customer_date  order_estimated_delivery_date
# 0                            267                            267
# 1                          43426                          43428
# 2                          52777                          52783

# %%
plt.figure(figsize=(8,6))
plt.plot(grouped_sales_by_year['year'],grouped_sales_by_year['order_purchase_timestamp'],marker='o')
plt.xticks(grouped_sales_by_year['year'])
plt.yticks(grouped_sales_by_year['order_purchase_timestamp'])
plt.xlabel('year')
plt.ylabel('orders delivered')
plt.title('orders delivered by year')
plt.show()

# %% [markdown]
# Dapat dilihat dari data di atas, grafik order delivered memiliki tren menaik dari tahun 2016 hingga tahun 2018. Hal ini menyatakan penjualan e-commerce mengalami kenaikan dari tahun 2016 hingga 2018.

# %% [markdown]
# ### Analisis penjualan berdasarkan bulan

# %%
sales_df['month']=sales_df['order_purchase_timestamp'].dt.month
sales_df=sales_df.astype({'month':'int64'})

sales_df_2016 = sales_df[sales_df['year']==2016]
sales_df_2017 = sales_df[sales_df['year']==2017]
sales_df_2018 = sales_df[sales_df['year']==2018]

# %%
sales_df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
grouped_orders_by_month_2016 = sales_df_2016.groupby(sales_df_2016['month']).count().reset_index()

months=['jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec']
plt.figure(figsize=(8,6))
month=[]
for i in grouped_orders_by_month_2016['month']:
    month.append(months[i-1])
plt.plot(month,grouped_orders_by_month_2016['order_purchase_timestamp'],marker='o')
plt.xticks(month)
plt.yticks(grouped_orders_by_month_2016['order_purchase_timestamp'])
plt.ylabel('orders delivered')
plt.title('orders delivered by month in 2016')
plt.show()

# %%
grouped_orders_by_month_2016
# Out:
#    month  order_id  customer_id  order_status  order_purchase_timestamp  \
# 0      9         1            1             1                         1
# 1     10       265          265           265                       265
# 2     12         1            1             1                         1
#
#    order_approved_at  order_delivered_carrier_date  \
# 0                  1                             1
# 1                265                           265
# 2                  1                             1
#
#    order_delivered_customer_date  order_estimated_delivery_date  year
# 0                              1                              1     1
# 1                            265                            265   265
# 2                              1                              1     1

# %% [markdown]
# Berdasarkan data, pada tahun 2016 hanya tercatat 267 penjualan, yaitu pada bulan september sebanyak 1, pada bulan oktober sebanyak 265, dan bulan desember sebanyak 1.

# %%
grouped_orders_by_month_2017 = sales_df_2017.groupby(sales_df_2017['month']).count().reset_index()

plt.figure(figsize=(15,12))
month=[]
for i in grouped_orders_by_month_2017['month']:
    month.append(months[i-1])
plt.plot(month,grouped_orders_by_month_2017['order_purchase_timestamp'],marker='o')
plt.xticks(month)
plt.yticks(grouped_orders_by_month_2017['order_purchase_timestamp'])
plt.ylabel('orders delivered')
plt.title('orders delivered by month in 2017')
plt.show()

# %% [markdown]
# Berdasarkan data di atas, penjualan pada tahun 2017 terus mengalami kenaikan. Grafik orders delivered menunjukkan tren kenaikan order sepanjang tahun. Hal ini menyatakan penjualan e-commerce pada tahun 2017 mengalami kenaikan dengan kenaikan tertinggi pada bulan november sebanyak 7289.

# %%
grouped_orders_by_month_2018 = sales_df_2018.groupby(sales_df_2018['month']).count().reset_index()

plt.figure(figsize=(8,6))
month=[]
for i in grouped_orders_by_month_2018['month']:
    month.append(months[i-1])
plt.plot(month,grouped_orders_by_month_2018['order_purchase_timestamp'],marker='o')
plt.xticks(month)
plt.yticks(grouped_orders_by_month_2018['order_purchase_timestamp'])
plt.ylabel('orders delivered')
plt.title('orders delivered by month in 2018')
plt.show()

# %% [markdown]
# Berdasarkan data, pada tahun 2018 orders delivered tetap bertahan di atas angka 6000 pada bulan januari hingga bulan agustus dengan penjualan tertinggi pada tahun 2018 terdapat pada bulan januari sebanyak 7069. Namun, grafik menunjukkan adanya penurunan penjualan dari bulan januari hingga bulan agustus pada tahun 2018.

# %%
grouped_orders_by_month_2018
# Out:
#    month  order_id  customer_id  order_status  order_purchase_timestamp  \
# 0      1      7069         7069          7069                      7069
# 1      2      6555         6555          6555                      6555
# 2      3      7003         7003          7003                      7003
# 3      4      6798         6798          6798                      6798
# 4      5      6749         6749          6749                      6749
# 5      6      6099         6099          6099                      6099
# 6      7      6159         6159          6159                      6159
# 7      8      6351         6351          6351                      6351
#
#    order_approved_at  order_delivered_carrier_date  \
# 0               7069                          7069
# 1               6555                          6555
# 2               7003                          7003
# 3               6798                          6798
# 4               6749                          6749
# ...

# %% [markdown]
# # Menganalisis produk yang paling banyak diorder

# %%
order_items_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %% [markdown]
# Untuk menganalisis produk apa yang paling banyak diorder, kita dapat menganalisis order_items dataset.

# %%
grouped_ordered_products = order_items_df.groupby(order_items_df['product_id']).count().reset_index().sort_values(by='order_id',ascending=False)
grouped_ordered_products.head(10)
# Out:
#                              product_id  order_id  order_item_id  seller_id  \
# 22112  aca2eb7d00ea1a7b8ebd4e68314663af       527            527        527
# 19742  99a4788cb24856965c36a24e339b6058       488            488        488
# 8613   422879e10f46682990de24d770e7f83d       484            484        484
# 7364   389d119b48cf3043d311335e499d9c6b       392            392        392
# 7079   368c6c730842d78016ad823897a372db       388            388        388
# 10840  53759a2ecddad2bb87a079a1f1519f73       373            373        373
# 27039  d1c427060a0f73f6b889a5c7c61f2ac4       343            343        343
# 10867  53b36df67ebb7c41585e8d54d6772e08       323            323        323
# 2794   154e7e31ebfa092203795c972e5804a6       281            281        281
# 8051   3dd2a17168ec895c781a9191c1e95ad7       274            274        274
#
#        shipping_limit_date  price  freight_value
# 22112                  527    527            527
# ...

# %%
# menambah kolom category name berdasarkan product id
grouped_ordered_products = pd.merge(grouped_ordered_products,products_df[['product_id','product_category_name']],on = 'product_id')

# %%
grouped_ordered_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32951 entries, 0 to 32950
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             32951 non-null  object
#  1   order_id               32951 non-null  int64
#  2   order_item_id          32951 non-null  int64
#  3   seller_id              32951 non-null  int64
#  4   shipping_limit_date    32951 non-null  int64
#  5   price                  32951 non-null  int64
#  6   freight_value          32951 non-null  int64
#  7   product_category_name  32341 non-null  object
# dtypes: int64(6), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# Selanjutnya, kita dapat mengubah nama produk menjadi bahasa inggris berdasarkan dataset product_category_name_translation.

# %%
product_category_name_translation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
product_category_name_english = []
for name in grouped_ordered_products['product_category_name']:
    add=True
    for n,en_name in zip(product_category_name_translation['product_category_name'],product_category_name_translation['product_category_name_english']):
        if name == n:
            product_category_name_english.append(en_name)
            add = False
    if add:
         product_category_name_english.append(n)

# %%
grouped_ordered_products['product_category_name_english']=product_category_name_english
grouped_ordered_products
# Out:
#                              product_id  order_id  order_item_id  seller_id  \
# 0      aca2eb7d00ea1a7b8ebd4e68314663af       527            527        527
# 1      99a4788cb24856965c36a24e339b6058       488            488        488
# 2      422879e10f46682990de24d770e7f83d       484            484        484
# 3      389d119b48cf3043d311335e499d9c6b       392            392        392
# 4      368c6c730842d78016ad823897a372db       388            388        388
# ...                                 ...       ...            ...        ...
# 32946  6ca99f05e9c1952a6597264e87f01378         1              1          1
# 32947  6ca54e191592a843087a042b0665d7ef         1              1          1
# 32948  6ca5428af5edb5066b1966ad58501b60         1              1          1
# 32949  6ca32b4631431cb1fe976880797a0f5c         1              1          1
# 32950  fffe9eeff12fcbd74a2f2b007dde0c58         1              1          1
#
# ...

# %%
# mengurutkan produk yang paling banyak diorder
top_ordered_products = grouped_ordered_products.groupby(grouped_ordered_products['product_category_name_english']).agg({
    'order_id':'sum'
}).reset_index()
top_ordered_products = top_ordered_products.sort_values(by='order_id',ascending=False)

# %%
top_ordered_products
# Out:
#    product_category_name_english  order_id
# 7                 bed_bath_table     11115
# 43                 health_beauty      9670
# 66                sports_leisure      8641
# 39               furniture_decor      8334
# 15         computers_accessories      7827
# ..                           ...       ...
# 3          arts_and_craftmanship        24
# 11             cds_dvds_musicals        14
# 52                    la_cuisine        14
# 29     fashion_childrens_clothes         8
# 61         security_and_services         2
#
# [72 rows x 2 columns]

# %%
top10_products = top_ordered_products.head(10)
colors = ["#00ffaa", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3","#D3D3D3","#D3D3D3","#D3D3D3","#D3D3D3","#D3D3D3"]
plt.figure(figsize=(12,10))
plt.barh(top10_products['product_category_name_english'],top10_products['order_id'])
plt.title('Top 10 most ordered products')

sns.barplot(x='order_id', y='product_category_name_english', data=top10_products, palette=colors)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis ='y', labelsize=12)
plt.show()

# %% [markdown]
# Berdasarkan data, dapat dilihat produk bed_bath_table merupakan produk yang paling banyak diorder dari e-commerce dengan total order mencapai 11115 order.

# %% [markdown]
# ### Menyimpan dataset grouped_ordered_products

# %%
grouped_ordered_products.to_csv('./dashboard/grouped_ordered_products.csv',index=False)

# %% [markdown]
# # RFM analysis

# %%
orders_df.sort_values(by='order_purchase_timestamp',ascending=False)
# Out:
#                                order_id                       customer_id  \
# 60938  10a045cdf6a5650c21e9cfeb60384c16  a4b417188addbc05b26b72d5e44837a1
# 68373  b059ee4de278302d550a3035c4cdb740  856336203359aa6a61bf3826f7d84c49
# 31891  a2ac6dad85cf8af5b0afb510a240fe8c  4c2ec60c29d10c34bd49cb88aa85cfc4
# 88500  616fa7d4871b87832197b2a137a115d2  bf6181a85bbb4115736c0a8db1a53be3
# 50387  392ed9afd714e3c74767d0c4d3e3f477  2823ffda607a2316375088e0d00005ec
# ...                                 ...                               ...
# 83078  71303d7e93b399f5bcd537d124c0bcfa  b106b360fe2ef8849fbbd056f777b4d5
# 30710  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 10071  809a282bbd5dbcabb6f2f724fca862ec  622e13439d6b5a0b486c435618b2679e
# 4396   e5fa5a7210941f7d56d0208e4e071d35  683c54fc24d40ee9f8a6fc179fd9856c
# 4541   2e7a8482f6fb09756ca50c10d7bfc047  08c5351a6aca1c1589a38f244edeee9d
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
order_payments_df.groupby(order_payments_df['order_id']).count().sort_values(by='payment_value',ascending=False)
# Out:
#                                   payment_sequential  payment_type  \
# order_id
# fa65dad1b0e818e3ccc5cb0e39231352                  29            29
# ccf804e764ed5650cd8759557269dc13                  26            26
# 285c2e15bebd4ac83635ccc563dc71f4                  22            22
# 895ab968e7bb0d5659d16cd74cd1650c                  21            21
# fedcd9f7ccdc8cba3a18defedd1a5547                  19            19
# ...                                              ...           ...
# 56bd45163229b35ca0ab490c1e3d3233                   1             1
# 56bc98e6d5b88c2cdb905f2fbec2ca3a                   1             1
# 56bbc7d92e6e74b8782abbf5ee336a92                   1             1
# 56bafc014f8ed2f34cfe598592c65fd8                   1             1
# fffe41c64501cc87c801fd61db3f6244                   1             1
#
#                                   payment_installments  payment_value
# order_id
# fa65dad1b0e818e3ccc5cb0e39231352                    29             29
# ...

# %%
order_payments_df[order_payments_df['order_id']=='bfbd0f9bdef84302105ad712db648a6c']
# Out:
# Empty DataFrame
# Columns: [order_id, payment_sequential, payment_type, payment_installments, payment_value]
# Index: []

# %%
# menggabungkan kolom payment value dengan orders dataset berdasarkan order_id
rfm_orders_df = orders_df
grouped_payments_by_id = order_payments_df.groupby(order_payments_df['order_id']).sum().reset_index()
rfm_orders_df = rfm_orders_df.merge(grouped_payments_by_id[['order_id','payment_value']],on='order_id',how='left')
rfm_orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
#  8   payment_value                  99440 non-null  float64
# dtypes: datetime64[ns](5), float64(1), object(3)
# memory usage: 7.6+ MB
# ...

# %%
# mencari order_id dengan kolom payment_value kosong
rfm_orders_df[rfm_orders_df['payment_value'].isna()]
# Out:
#                                order_id                       customer_id  \
# 30710  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 30710    delivered      2016-09-15 12:16:38 2016-09-15 12:16:38
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 30710          2016-11-07 17:11:53           2016-11-09 07:47:38
#
#       order_estimated_delivery_date  payment_value
# 30710                    2016-10-04            NaN

# %%
rfm_df = rfm_orders_df.groupby(by="customer_id", as_index=False).agg({
    "order_purchase_timestamp": "max", 
    "order_id": "nunique", 
    "payment_value": "sum" 
})
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]
 
# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = orders_df["order_purchase_timestamp"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)
 
rfm_df.drop("max_order_timestamp", axis=1, inplace=True)

# %%
rfm_orders_df.sort_values(by='order_purchase_timestamp',ascending=False)
# Out:
#                                order_id                       customer_id  \
# 60938  10a045cdf6a5650c21e9cfeb60384c16  a4b417188addbc05b26b72d5e44837a1
# 68373  b059ee4de278302d550a3035c4cdb740  856336203359aa6a61bf3826f7d84c49
# 31891  a2ac6dad85cf8af5b0afb510a240fe8c  4c2ec60c29d10c34bd49cb88aa85cfc4
# 88500  616fa7d4871b87832197b2a137a115d2  bf6181a85bbb4115736c0a8db1a53be3
# 50387  392ed9afd714e3c74767d0c4d3e3f477  2823ffda607a2316375088e0d00005ec
# ...                                 ...                               ...
# 83078  71303d7e93b399f5bcd537d124c0bcfa  b106b360fe2ef8849fbbd056f777b4d5
# 30710  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 10071  809a282bbd5dbcabb6f2f724fca862ec  622e13439d6b5a0b486c435618b2679e
# 4396   e5fa5a7210941f7d56d0208e4e071d35  683c54fc24d40ee9f8a6fc179fd9856c
# 4541   2e7a8482f6fb09756ca50c10d7bfc047  08c5351a6aca1c1589a38f244edeee9d
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(27, 30))
colors = ["#00ffaa"]*5
 
sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)
 
sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)
 
sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)
 
plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=30)
plt.show()

# %% [markdown]
# Berdasarkan hasil analisis segmentasi customer berdasarkan RFM, frekuensi order customer pada e-commerce paling banyak hanya 1 kali. Berdasarkan monetary terdapat beberapa customer yang melakukan transaksi yang cukup besar dalam satu transaksi dengan transaksi tertinggi hampir mencapai 14000 dalam satu transaksi. Berdasarkan recency interaksi customer dengan e-commerce cukup bervariasi dengan interaksi terbaru berdasarkan dataset adalah 2018-10-17 oleh customer dengan id pertama pada grafik recency.

# %% [markdown]
# ### Menyimpan dataset yang digunakan untuk analisis RFM

# %%
rfm_orders_df['year'] = rfm_orders_df['order_purchase_timestamp'].dt.year
rfm_orders_df['month'] = rfm_orders_df['order_purchase_timestamp'].dt.month

# %%
rfm_orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
#  8   payment_value                  99440 non-null  float64
#  9   year                           99441 non-null  int64
#  10  month                          99441 non-null  int64
# ...

# %%
rfm_orders_df.to_csv('./dashboard/rfm_orders_df.csv',index=False)
